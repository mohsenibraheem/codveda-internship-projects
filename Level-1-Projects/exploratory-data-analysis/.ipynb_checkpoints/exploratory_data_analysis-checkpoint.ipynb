# %% [markdown]
# #### **<h1 align="center"><span style="color:#06445e;">Exploratory Data Analysis (EDA)</span>**

# %% [markdown]
# #### **<h2 align="center"><span style="color:#06445e;">Task</span>**
# ### **Description: Perform an exploratory analysis on a given dataset to identify patterns, trends, and summary statistics.**

# %% [markdown]
# #### **<h2 align="center"><span style="color:#06445e;">Objectives:</span>**

# %% [markdown]
# ### Calculate summary statistics (mean, median, mode, standard deviation).
# ### Visualize data distributions using histograms, boxplots, and scatter plots.
# ### Find correlations between numerical features

# %% [markdown]
# ## Import Libraries

# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ## Load data

# %%
stock_price_df = pd.read_csv("dataset/stock_prices.csv")

# %% [markdown]
# ## Start Exploratory Data Analysis

# %% [markdown]
# ### Data  Inspection

# %% [markdown]
# #### Top 5 rows of the data

# %%
stock_price_df.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %% [markdown]
# #### Last 5 rows of the data

# %%
stock_price_df.tail()
# Out:
#        symbol        date    open    high     low   close   volume
# 497467    XYL  2017-12-29   68.53   68.80   67.92   68.20  1046677
# 497468    YUM  2017-12-29   82.64   82.71   81.59   81.61  1347613
# 497469    ZBH  2017-12-29  121.75  121.95  120.62  120.67  1023624
# 497470   ZION  2017-12-29   51.28   51.55   50.81   50.83  1261916
# 497471    ZTS  2017-12-29   72.55   72.76   72.04   72.04  1704122

# %% [markdown]
# #### Basic information about the data

# %%
stock_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497472 entries, 0 to 497471
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  497472 non-null  object
#  1   date    497472 non-null  object
#  2   open    497461 non-null  float64
#  3   high    497464 non-null  float64
#  4   low     497464 non-null  float64
#  5   close   497472 non-null  float64
#  6   volume  497472 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.6+ MB

# %% [markdown]
# #### Basic information about the data

# %%
stock_price_df.dtypes
# Out:
# symbol     object
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# dtype: object

# %% [markdown]
# ### Check missing values

# %%
stock_price_df.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %% [markdown]
# #### Check duplicate records

# %%
stock_price_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Check unique values

# %%
stock_price_df["symbol"].value_counts()
# Out:
# symbol
# AAL     1007
# PRGO    1007
# NVDA    1007
# NUE     1007
# NTRS    1007
#         ...
# DXC      189
# BHGE     126
# BHF      117
# DWDP      83
# APTV      18
# Name: count, Length: 505, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Impute the columns with null values, using time series based methods by imputing with previous valid price.

# %%
stock_price_df.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
stock_price_df["open"] = stock_price_df["open"].ffill()
stock_price_df["high"] = stock_price_df["high"].ffill()
stock_price_df["low"] = stock_price_df["low"].ffill()

# %% [markdown]
# #### Standardise "Date" columnn's format

# %%
stock_price_df["date"] = pd.to_datetime(stock_price_df["date"])

# %% [markdown]
# #### After imputing null values

# %%
stock_price_df.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# ### Calculating Summary Statistics

# %% [markdown]
# #### Basic statistics description of the data

# %%
stock_price_df.describe().T
# Out:
#            count                           mean                  min  \
# date      497472  2016-01-06 17:16:00.439984896  2014-01-02 00:00:00
# open    497472.0                      86.351835                 1.62
# high    497472.0                      87.131986                 1.69
# low     497472.0                      85.551898                  1.5
# close   497472.0                      86.369082                 1.59
# volume  497472.0                 4253610.897777                  0.0
#
#                         25%                  50%                  75%  \
# date    2015-01-08 00:00:00  2016-01-11 00:00:00  2017-01-06 00:00:00
# open                  41.69                64.97                98.41
# high                  42.09                65.56                99.23
# low                   41.28                64.35                97.58
# close              41.70375                64.98                98.42
# ...

# %%
print("Mean of Numeric columns")
stock_price_df.mean(numeric_only = True)
# Out:
# Mean of Numeric columns
# open      8.635183e+01
# high      8.713199e+01
# low       8.555190e+01
# close     8.636908e+01
# volume    4.253611e+06
# dtype: float64

# %%
print("Median of Numeric columns")
stock_price_df.median(numeric_only = True)
# Out:
# Median of Numeric columns
# open           64.97
# high           65.56
# low            64.35
# close          64.98
# volume    2084896.50
# dtype: float64

# %%
print("Standard Deviation:")
stock_price_df.std(numeric_only = True)
# Out:
# Standard Deviation:
# open      1.014704e+02
# high      1.023114e+02
# low       1.005703e+02
# close     1.014724e+02
# volume    8.232139e+06
# dtype: float64

# %% [markdown]
# #### Top 20 Company symbol that appeared the most

# %%
stock_price_df["symbol"].value_counts().head(20)
# Out:
# symbol
# AAL     1007
# PRGO    1007
# NVDA    1007
# NUE     1007
# NTRS    1007
# NTAP    1007
# NSC     1007
# NRG     1007
# NOV     1007
# NOC     1007
# NLSN    1007
# NKE     1007
# NI      1007
# NFX     1007
# NFLX    1007
# NEM     1007
# NEE     1007
# NDAQ    1007
# NCLH    1007
# NBL     1007
# Name: count, dtype: int64

# %% [markdown]
# #### Relationship between numerical variables

# %%
stock_price_df.corr(numeric_only = True)
# Out:
#             open      high       low     close    volume
# open    1.000000  0.999937  0.999924  0.999852 -0.148721
# high    0.999937  1.000000  0.999905  0.999917 -0.148341
# low     0.999924  0.999905  1.000000  0.999921 -0.149281
# close   0.999852  0.999917  0.999921  1.000000 -0.148839
# volume -0.148721 -0.148341 -0.149281 -0.148839  1.000000

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize= (8,5))
sns.histplot(stock_price_df["close"], bins = 50, kde=True)
plt.title("Distribution of Close Price")
plt.show()

# %%
plt.figure(figsize= (8,5))
sns.histplot(stock_price_df["volume"], bins = 50, kde=True)
plt.title("Distribution of Trading Volume")
plt.show()

# %%
cols = ["open", "high", "low", "close"]
plt.figure(figsize= (10,6))
sns.boxplot(data = stock_price_df[cols])
plt.title("Stock Price Distribution (Open, High, Low, Close)")
plt.show()

# %%
plt.figure(figsize= (6,5))
sns.boxplot(x = stock_price_df["volume"])
plt.title("Volume Outliers")
plt.show()

# %%
plt.figure(figsize= (6,5))
sns.scatterplot(x =stock_price_df["open"], y = stock_price_df["close"])
plt.title("Open vs Close Price")
plt.show()

# %%
stock_price_df.head()
# Out:
#   symbol       date      open      high       low     close    volume
# 0    AAL 2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL 2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP 2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV 2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC 2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
data = stock_price_df[["open","high","low","volume","close"]]

plt.figure(figsize= (8,6))
sns.heatmap(data.corr(), annot = True, cmap="coolwarm")
plt.title("Correlation of Numerical Variables")
plt.show()

# %%
stock_price_df = stock_price_df.sort_values("date")

plt.figure(figsize = (12,6))
sns.lineplot(x="date", y= "close", data = stock_price_df)
plt.title("Closing Price Over  Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### **<h2 align="center"><span style="color:#06445e;">Key Insights:</span>**

# %% [markdown]
# ### **The stock experienced unsually high trading activity on certain days, which may indicate significant market events or investors reactions.**
